# %%
import pandas as pd
import os

# %% [markdown]
# # **Readind data**

# %%
data = pd.read_csv('2022-2023 Football Player Stats.csv',   sep = ';', encoding = 'ISO-8859-1')
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    Rk             Player Nation   Pos         Squad            Comp  Age  \
# 0   1   Brenden Aaronson    USA  MFFW  Leeds United  Premier League   22
# 1   2   Yunis Abdelhamid    MAR    DF         Reims         Ligue 1   35
# 2   3      Himad Abdelli    FRA  MFFW        Angers         Ligue 1   23
# 3   4  Salis Abdul Samed    GHA    MF          Lens         Ligue 1   22
# 4   5    Laurent Abergel    FRA    MF       Lorient         Ligue 1   30
#
#    Born  MP  Starts   Min   90s  Goals  Shots   SoT  SoT%  G/Sh  G/SoT  \
# 0  2000  20      19  1596  17.7      1   1.53  0.28  18.5  0.04   0.20
# 1  1987  22      22  1980  22.0      0   0.86  0.05   5.3  0.00   0.00
# 2  1999  14       8   770   8.6      0   1.05  0.35  33.3  0.00   0.00
# 3  2000  20      20  1799  20.0      1   0.60  0.15  25.0  0.08   0.33
# 4  1993  15      15  1165  12.9      0   0.31  0.00   0.0  0.00   0.00
#
#    ShoDist  ShoFK  ShoPK  PKatt  PasTotCmp  PasTotAtt  PasTotCmp%  PasTotDist  \
# ...

# %%
data = data.drop(['Rk', 'Born', 'PasAtt', 'Crs' , 'Nation'], axis = 1)
data.head()
# Out:
#               Player   Pos         Squad            Comp  Age  MP  Starts  \
# 0   Brenden Aaronson  MFFW  Leeds United  Premier League   22  20      19
# 1   Yunis Abdelhamid    DF         Reims         Ligue 1   35  22      22
# 2      Himad Abdelli  MFFW        Angers         Ligue 1   23  14       8
# 3  Salis Abdul Samed    MF          Lens         Ligue 1   22  20      20
# 4    Laurent Abergel    MF       Lorient         Ligue 1   30  15      15
#
#     Min   90s  Goals  Shots   SoT  SoT%  G/Sh  G/SoT  ShoDist  ShoFK  ShoPK  \
# 0  1596  17.7      1   1.53  0.28  18.5  0.04   0.20     19.0   0.11    0.0
# 1  1980  22.0      0   0.86  0.05   5.3  0.00   0.00     13.5   0.00    0.0
# 2   770   8.6      0   1.05  0.35  33.3  0.00   0.00     19.2   0.00    0.0
# 3  1799  20.0      1   0.60  0.15  25.0  0.08   0.33     20.3   0.00    0.0
# 4  1165  12.9      0   0.31  0.00   0.0  0.00   0.00     23.9   0.00    0.0
#
# ...

# %% [markdown]
# # **Create new dataframe form the original one **

# %%
df_data = pd.DataFrame()
df_data['Player'] = data['Player']
#df_data['Nation'] = data['Nation']
df_data['Pos'] = data['Pos']
df_data['Squad'] = data['Squad']
df_data['Comp'] = data['Comp']
df_data['Age'] = data['Age']
df_data['MP'] = data['MP']
df_data['G/90'] = data['Goals']
#df_data['G/Sh'] = data['G/Sh']
#df_data['PKGoals'] = ((data['ShoPK'] * data['Min']) / 90).round(0).astype(int)
#df_data['PKAttempted'] = ((data['PKatt'] * data['Min']) / 90).round(0).astype(int)
#df_data['Goals'] = ((data['Goals'] * data['Min']) / 90).round(0).astype(int)
df_data['Pass'] = ((data['PasTotAtt'] * data['Min']) / 90).round(0).astype(int)
df_data['PassCompleted'] = ((data['PasTotCmp'] * data['Min']) / 90).round(0).astype(int)
df_data['PassComp%'] = ((df_data['PassCompleted'] / df_data['Pass']) * 100).round(2)
df_data['Assist'] = ((data['Assists'] * data['Min']) / 90).round(0).astype(int)
df_data['Cross'] = ((data['PasCrs'] * data['Min']) / 90).round(0).astype(int)
df_data['CrossCompleted'] = ((data['CrsPA'] * data['Min']) / 90).round(0).astype(int)
df_data['CrossComp%'] = ((df_data['CrossCompleted'] / df_data['Cross']) * 100).round(2)
df_data['Tackle_Won'] = ((data['TklWon'] * data['Min']) / 90).round(0).astype(int)
#df_data['SucDribble'] = ((data['DriSucc'] * data['Min']) / 90).round(0).astype(int)
#df_data['Dribble'] = ((data['DriAtt'] * data['Min']) / 90).round(0).astype(int)
#df_data['DribbleComp%'] = ((df_data['SucDribble'] / df_data['Dribble']) * 100).round(2)
#df_data['YCards'] = ((data['CrdY'] * data['Min']) / 90).round(0).astype(int)
#df_data['RCards'] = ((data['CrdR'] * data['Min']) / 90).round(0).astype(int)
#df_data['Fls'] = ((data['Fls'] * data['Min']) / 90).round(0).astype(int)
#df_data['Fld'] = ((data['Fld'] * data['Min']) / 90).round(0).astype(int)
#df_data['OGoals'] = ((data['OG'] * data['Min']) / 90).round(0).astype(int)
df_data['AerWon'] = ((data['AerWon'] * data['Min']) / 90).round(0).astype(int)
df_data['AerLost'] = ((data['AerLost'] * data['Min']) / 90).round(0).astype(int)
df_data['AerWon%'] = ((data['AerWon'] / (data['AerWon'] + data['AerLost'])) * 100).round(2)
df_data.head()
# Out:
#               Player   Pos         Squad            Comp  Age  MP  G/90  Pass  \
# 0   Brenden Aaronson  MFFW  Leeds United  Premier League   22  20     1   550
# 1   Yunis Abdelhamid    DF         Reims         Ligue 1   35  22     0  1038
# 2      Himad Abdelli  MFFW        Angers         Ligue 1   23  14     0   424
# 3  Salis Abdul Samed    MF          Lens         Ligue 1   22  20     1  1297
# 4    Laurent Abergel    MF       Lorient         Ligue 1   30  15     0   562
#
#    PassCompleted  PassComp%  Assist  Cross  CrossCompleted  CrossComp%  \
# 0            411      74.73       2     45               2        4.44
# 1            847      81.60       1      4               0        0.00
# 2            342      80.66       0      9               3       33.33
# 3           1189      91.67       0      7               2       28.57
# 4            491      87.37       1      3               0        0.00
#
#    Tackle_Won  AerWon  AerLost  AerWon%
# ...

# %%
import numpy as np
new_data = df_data[ (df_data['Squad'] != 'Barcelona') & (df_data['Squad'] !='Real Madrid') & (df_data['Squad'] !='Liverpool') & (df_data['Squad'] !='Manchester City') & (df_data['Squad'] !='Chelsea') & (df_data['Squad'] !='Napoli')].index
df_data.drop(new_data, inplace=True)
#df_data.drop([1629 , 1978 , 2452 ], axis=0, inplace=True)
df_data
# Out:
#                           Player   Pos            Squad            Comp  Age  \
# 42                 Manuel Akanji    DF  Manchester City  Premier League   27
# 43                    Nathan Aké    DF  Manchester City  Premier League   27
# 49                   David Alaba    DF      Real Madrid         La Liga   30
# 52                    Jordi Alba    DF        Barcelona         La Liga   33
# 56              Thiago Alcántara    MF        Liverpool  Premier League   31
# ...                          ...   ...              ...             ...  ...
# 2651  Andre-Frank Zambo Anguissa    MF           Napoli         Serie A   27
# 2656           Alessandro Zanoli    DF           Napoli         Serie A   22
# 2667              Alessio Zerbin    FW           Napoli         Serie A   23
# 2671             Piotr Zieli?ski    MF           Napoli         Serie A   28
# 2675                Hakim Ziyech  FWMF          Chelsea  Premier League   29
#
# ...

# %%
df_data["Squad"].value_counts()
# Out:
# Chelsea            32
# Liverpool          27
# Barcelona          25
# Napoli             24
# Real Madrid        22
# Manchester City    21
# Name: Squad, dtype: int64

# %%
df_data = df_data.sort_values(by = ['Squad'])
df_data
# Out:
#                  Player   Pos        Squad     Comp  Age  MP  G/90  Pass  \
# 1629            Memphis    FW    Barcelona  La Liga   28   2     1    64
# 924         Eric García    DF    Barcelona  La Liga   22  11     1   650
# 935                Gavi  MFFW    Barcelona  La Liga   18  20     1   662
# 634     Ousmane Dembélé    FW    Barcelona  La Liga   25  18     5   648
# 1214    Frenkie de Jong    MF    Barcelona  La Liga   25  18     2  1113
# ...                 ...   ...          ...      ...  ...  ..   ...   ...
# 1553            Mariano    FW  Real Madrid  La Liga   29   5     0    10
# 2133    Antonio Rüdiger    DF  Real Madrid  La Liga   29  18     1   801
# 409   Eduardo Camavinga  MFDF  Real Madrid  La Liga   20  20     0   637
# 1685        Luka Modri?    MF  Real Madrid  La Liga   37  19     3   936
# 1662       Éder Militão    DF  Real Madrid  La Liga   25  16     3   759
#
#       PassCompleted  PassComp%  Assist  Cross  CrossCompleted  CrossComp%  \
# ...

# %%
(df_data[(df_data.MP >= 20) & (df_data.Pos != 'GK')].sort_values('G/90', ascending = False)).head().iloc[: , [0,1,2,3,4,5,6]]
# Out:
#                  Player   Pos            Squad            Comp  Age  MP  G/90
# 1057     Erling Haaland    FW  Manchester City  Premier League   22  20    25
# 1233    Vinicius Júnior    FW      Real Madrid         La Liga   22  20     7
# 2168      Mohamed Salah    FW        Liverpool  Premier League   30  20     7
# 2513  Federico Valverde  FWMF      Real Madrid         La Liga   24  20     6
# 1082        Kai Havertz  FWMF          Chelsea  Premier League   23  21     5

# %%
team_goals = df_data.groupby(['Squad']).agg(Team_Goals = ('G/90', 'sum'))
team_goals = pd.DataFrame(team_goals).reset_index()
team_goals.sort_values('Team_Goals', ascending = False).head(6)
# Out:
#              Squad  Team_Goals
# 3  Manchester City          52
# 4           Napoli          51
# 0        Barcelona          42
# 5      Real Madrid          40
# 2        Liverpool          30
# 1          Chelsea          23

# %%
(df_data[df_data.MP >= 20].sort_values('PassCompleted', ascending = False)
                                            .head(5)
                                            .iloc[:, [0,1,2,3,4,5,8]])
# Out:
#                    Player Pos            Squad            Comp  Age  MP  \
# 2098                Rodri  MF  Manchester City  Premier League   26  20
# 2272         Thiago Silva  DF          Chelsea  Premier League   38  20
# 1669          Kim Min-jae  DF           Napoli         Serie A   26  20
# 660   Giovanni Di Lorenzo  DF           Napoli         Serie A   29  21
# 1448    Stanislav Lobotka  MF           Napoli         Serie A   28  21
#
#       PassCompleted
# 2098           1702
# 2272           1451
# 1669           1383
# 660            1317
# 1448           1223

# %%
team_pass_comp = df_data.groupby(['Squad']).agg(Pass_Attempted = ('Pass', 'sum'), Pass_Completion = ('PassCompleted', 'sum'))
team_pass_comp = pd.DataFrame(team_pass_comp).reset_index()
team_pass_comp['PassComp%'] = ((team_pass_comp['Pass_Completion'] / team_pass_comp['Pass_Attempted']) * 100).round(2)
team_pass_comp = team_pass_comp.sort_values('PassComp%', ascending = False).head(6).iloc[:, [0,-1]]
team_pass_comp
# Out:
#              Squad  PassComp%
# 5      Real Madrid      88.15
# 3  Manchester City      87.35
# 0        Barcelona      87.03
# 4           Napoli      85.63
# 1          Chelsea      83.16
# 2        Liverpool      81.18

# %%
(df_data[(df_data.MP >= 18) & (df_data.Pos.str.contains('DF'))].sort_values('AerWon%', ascending = False)
                                                                                             .head(5)
                                                                                             .iloc[:, [0,1,2,3,4,5,17]])
# Out:
#                       Player Pos        Squad            Comp  Age  MP  \
# 2133         Antonio Rüdiger  DF  Real Madrid         La Liga   29  18
# 2272            Thiago Silva  DF      Chelsea  Premier League   38  20
# 1669             Kim Min-jae  DF       Napoli         Serie A   26  20
# 63    Trent Alexander-Arnold  DF    Liverpool  Premier League   24  20
# 155        César Azpilicueta  DF      Chelsea  Premier League   33  18
#
#       AerWon%
# 2133    73.30
# 2272    68.44
# 1669    64.00
# 63      61.06
# 155     59.38

# %%
team_aerial_won = df_data.groupby(['Squad']).agg(AerWon = ('AerWon', 'sum'),
                                                           AerLost = ('AerLost', 'sum'))
team_aerial_won = pd.DataFrame(team_aerial_won).reset_index()
team_aerial_won['AerWon%'] = ((team_aerial_won['AerWon'] / (team_aerial_won['AerWon'] + team_aerial_won['AerLost'])) * 100).round(2)
team_aerial_won.sort_values('AerWon%', ascending = False).head(6).iloc[:, [0,-1]]
# Out:
#              Squad  AerWon%
# 5      Real Madrid    58.62
# 3  Manchester City    57.83
# 4           Napoli    54.76
# 0        Barcelona    54.64
# 1          Chelsea    51.83
# 2        Liverpool    48.80

# %%
(df_data[df_data.MP >= 15].sort_values('CrossCompleted', ascending = False)
                                            .head(5)
                                            .iloc[:, [0,1,2,3,4,5,12]])
# Out:
#                       Player Pos            Squad            Comp  Age  MP  \
# 63    Trent Alexander-Arnold  DF        Liverpool  Premier League   24  20
# 612          Kevin De Bruyne  MF  Manchester City  Premier League   31  20
# 1471          Hirving Lozano  FW           Napoli         Serie A   27  20
# 2137               Mário Rui  DF           Napoli         Serie A   31  17
# 2090        Andrew Robertson  DF        Liverpool  Premier League   28  18
#
#       CrossCompleted
# 63                17
# 612               14
# 1471              14
# 2137              12
# 2090              10

# %%
(df_data[(df_data.MP >= 15) & (df_data.Pos.str.contains('MF'))].sort_values('CrossComp%', ascending = False)
                                                                                             .head(5)
                                                                                             .iloc[:, [0,1,2,3,4,5,13]])
# Out:
#                 Player   Pos            Squad            Comp  Age  MP  \
# 378    Sergio Busquets    MF        Barcelona         La Liga   34  18
# 1327     Mateo Kova?i?    MF          Chelsea  Premier League   28  15
# 2098             Rodri    MF  Manchester City  Premier League   26  20
# 1092  Jordan Henderson    MF        Liverpool  Premier League   32  17
# 779         Elif Elmas  FWMF           Napoli         Serie A   23  20
#
#       CrossComp%
# 378       100.00
# 1327       50.00
# 2098       33.33
# 1092       33.33
# 779        28.57

# %%
team_cross_comp = df_data.groupby(['Squad']).agg(Cross_Attempted = ('Cross', 'sum'),
                                                           Cross_Completion = ('CrossCompleted', 'sum'))
team_cross_comp = pd.DataFrame(team_cross_comp).reset_index()
team_cross_comp['CrossComp%'] = ((team_cross_comp['Cross_Completion'] / team_cross_comp['Cross_Attempted']) * 100).round(2)
team_cross_comp = team_cross_comp.sort_values('CrossComp%', ascending = False).head(5).iloc[:, [0,-1]]
team_cross_comp
# Out:
#              Squad  CrossComp%
# 4           Napoli       14.04
# 0        Barcelona       13.54
# 1          Chelsea       11.29
# 3  Manchester City       11.18
# 2        Liverpool       10.79

# %%
df_data.sort_values('Assist', ascending = False).head(8).iloc[:, [0,1,2,3,4,5,10]]
# Out:
#                      Player   Pos            Squad            Comp  Age  MP  \
# 612         Kevin De Bruyne    MF  Manchester City  Premier League   31  20
# 1348  Khvicha Kvaratskhelia    FW           Napoli         Serie A   22  17
# 2137              Mário Rui    DF           Napoli         Serie A   31  17
# 2671        Piotr Zieli?ski    MF           Napoli         Serie A   28  21
# 2107                Rodrygo    FW      Real Madrid         La Liga   22  18
# 2268         Bernardo Silva  MFFW  Manchester City  Premier League   28  20
# 2090       Andrew Robertson    DF        Liverpool  Premier League   28  18
# 634         Ousmane Dembélé    FW        Barcelona         La Liga   25  18
#
#       Assist
# 612       11
# 1348       9
# 2137       6
# 2671       6
# 2107       5
# 2268       5
# 2090       5
# 634        5

# %%
df_data.sort_values('Tackle_Won', ascending = False).head(5).iloc[:, [0,1,2,3,4,5,14]]
# Out:
#                  Player Pos            Squad            Comp  Age  MP  \
# 2098              Rodri  MF  Manchester City  Premier League   26  20
# 1448  Stanislav Lobotka  MF           Napoli         Serie A   28  21
# 56     Thiago Alcántara  MF        Liverpool  Premier League   31  14
# 1218           Jorginho  MF          Chelsea  Premier League   31  18
# 1669        Kim Min-jae  DF           Napoli         Serie A   26  20
#
#       Tackle_Won
# 2098          28
# 1448          24
# 56            23
# 1218          23
# 1669          22

# %%
team_tackle_won = df_data.groupby(['Squad']).agg(Team_TackleWon = ('Tackle_Won', 'sum'))
team_tackle_won = pd.DataFrame(team_tackle_won).reset_index()
team_tackle_won.sort_values('Team_TackleWon', ascending = False).head(6)
# Out:
#              Squad  Team_TackleWon
# 1          Chelsea             244
# 0        Barcelona             191
# 2        Liverpool             182
# 4           Napoli             177
# 5      Real Madrid             174
# 3  Manchester City             155

# %%
(df_data[(df_data.MP >= 10) & (df_data.Pos.str.contains('DF'))].sort_values('AerWon%', ascending = False)
                                                                                             .head(5)
                                                                                             .iloc[:, [0,1,2,3,4,5,17]])
# Out:
#                Player   Pos            Squad            Comp  Age  MP  AerWon%
# 2581      Kyle Walker    DF  Manchester City  Premier League   32  11    80.00
# 2514  Virgil van Dijk    DF        Liverpool  Premier League   31  17    78.53
# 492      Ben Chilwell  DFMF          Chelsea  Premier League   26  11    76.19
# 2133  Antonio Rüdiger    DF      Real Madrid         La Liga   29  18    73.30
# 418      João Cancelo    DF  Manchester City  Premier League   28  17    71.16

# %%
df_data.head(10)
# Out:
#                Player   Pos      Squad     Comp  Age  MP  G/90  Pass  \
# 2042         Raphinha    FW  Barcelona  La Liga   26  19     4   629
# 1324     Jules Koundé    DF  Barcelona  La Liga   24  13     0   913
# 1285    Franck Kessié    MF  Barcelona  La Liga   26  12     0   168
# 1629          Memphis    FW  Barcelona  La Liga   28   2     1    64
# 1214  Frenkie de Jong    MF  Barcelona  La Liga   25  18     2  1113
# 1920            Pedri  MFFW  Barcelona  La Liga   20  20     5  1125
# 935              Gavi  MFFW  Barcelona  La Liga   18  20     1   662
# 924       Eric García    DF  Barcelona  La Liga   22  11     1   650
# 823         Ansu Fati    FW  Barcelona  La Liga   20  20     3   335
# 1978     Gerard Piqué    DF  Barcelona  La Liga   36   6     0   382
#
#       PassCompleted  PassComp%  Assist  Cross  CrossCompleted  CrossComp%  \
# 2042            467      74.24       4     83              10       12.05
# ...

# %%
out1 = np.array([30 ,30 ,16,10, 17 , 20 , 20 , 20 , 17, 5 , 25 , 2 , 10, 10, 15 , 30 , 5, 30 , 15 , 20 , 12 , 10 , 9  , 7 , 13 , 11 , 8 , 9 , 13 , 9 , 32 , 6 , 10 , 30 , 10 , 7 , 45 , 40 , 20 , 8 , 7 , 30 , 40 , 18 , 30 , 6 , 15 , 13 , 8 , 20 , 34 , 28, 11 , 30 , 9 , 30 , 16 , 24 , 35 , 30 , 38 , 36 , 25 , 50 , 13 , 29 , 26 , 8 , 26, 34 ,15 , 18 , 55 , 15 , 40 , 22 , 9 , 18 , 30 , 20 , 30 , 36 , 32 , 18 , 4 ,8 , 30 , 50 , 18 , 36 , 3 , 29 , 11 , 30 , 7 ,12 , 23 , 33 , 21 , 32 , 33 , 4 , 12 , 34, 21, 21, 34, 12 , 13 , 22 , 15 , 11, 13, 14,17, 18 , 191 , 6 , 7, 5, 9, 7, 6, 5, 9, 4 ,8 ])

df_data['Market value / M'] = out1
df_data
# Out:
#                Player   Pos      Squad     Comp  Age  MP  G/90  Pass  \
# 1629          Memphis    FW  Barcelona  La Liga   28   2     1    64
# 924       Eric García    DF  Barcelona  La Liga   22  11     1   650
# 935              Gavi  MFFW  Barcelona  La Liga   18  20     1   662
# 634   Ousmane Dembélé    FW  Barcelona  La Liga   25  18     5   648
# 1214  Frenkie de Jong    MF  Barcelona  La Liga   25  18     2  1113
#
#       PassCompleted  PassComp%  Assist  Cross  CrossCompleted  CrossComp%  \
# 1629             52      81.25       0      4               0        0.00
# 924             593      91.23       0      0               0         NaN
# 935             571      86.25       2     24               3       12.50
# 634             500      77.16       5     71               4        5.63
# 1214            998      89.67       1     11               3       27.27
#
#       Tackle_Won  AerWon  AerLost  AerWon%  Market value / M
# ...

# %%
X = df_data[[ 'G/90','Assist', 'Pass' , 'PassCompleted'  , 'Tackle_Won' , 'AerWon' , 'Cross' , 'CrossCompleted' ,'AerLost'  ]]
y= df_data['Market value / M']
X['G/90'].replace(0,1)
y.replace(0,4)
X['Assist'].replace(0,1)
X['Pass'].replace(0,1)
X['PassCompleted'].replace(0,1)
X['Tackle_Won'].replace(0,1)
X['AerWon'].replace(0,1)
X['AerLost'].replace(0,1)
X['Cross'].replace(0,1)
X['CrossCompleted'].replace(0,1)
X.isnull().sum()
# Out:
# G/90              0
# Assist            0
# Pass              0
# PassCompleted     0
# Tackle_Won        0
# AerWon            0
# Cross             0
# CrossCompleted    0
# AerLost           0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(X.corr(), annot=True , cmap='Blues' , fmt='.2f')
plt.show()

# %%
from tables import Cols
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, PolynomialFeatures
from sklearn.pipeline import Pipeline, FeatureUnion
#!pip install sklearn_features
from sklearn_features.transformers import DataFrameSelector


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

num_pipeline = Pipeline(steps=[
                        ('imputer', SimpleImputer(strategy='median')),
                        ('scaler', StandardScaler())
                              ]
                       )


from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)

rmse_scores_lin = cross_val_score(estimator=lin_reg, X=X_train, y=y_train,
                               cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

rmse_scores_lin = -1 * rmse_scores_lin  ## we want it positive
rmse_scores_lin = np.sqrt(rmse_scores_lin)

print('linear regression Train Score is : ' , lin_reg.score(X_train, y_train))
print('linear regression Test Score is : ' , lin_reg.score(X_test, y_test))
rmse_scores_lin.mean()
y_pred_reg= cross_val_predict(estimator=lin_reg, X=X_train, y=y_train, cv=5, method='predict', n_jobs=-1)
#y_pred_reg.round(2)
#rmse_scores_lin.mean()
# Out:
# linear regression Train Score is :  0.6941918586206838
# linear regression Test Score is :  0.398745898714329

# %%
y_pred_lin = cross_val_predict(estimator=lin_reg, X=X_train, y=y_train, cv=5, method='predict', n_jobs=-1)
y_pred_lin.round(2)
import joblib
joblib.dump(lin_reg , 'model_linreg.pkl')
joblib.load('model_linreg.pkl')
# Out:
# LinearRegression()

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.datasets import load_iris

# Load the iris dataset
#iris = load_iris()

# Split the data into training and testing sets
#X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)

# Create a support vector machine classifier
svm = SVC(random_state=42)

# Define the parameter grid to search over
param_grid = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}

# Create a GridSearchCV object
grid_search = GridSearchCV(svm, param_grid, cv=5, n_jobs=-1)

# Fit the GridSearchCV object to the training data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters and corresponding score
print("Best hyperparameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)

# Change the hyperparameters of the SVM
svm.C = 10
svm.kernel = 'rbf'

# Fit the SVM to the training data with the new hyperparameters
svm.fit(X_train, y_train)

# Compute the accuracy of the SVM on the test data
accuracy = svm.score(X_test, y_test)

# Print the accuracy of the SVM on the test data
print("Accuracy: ", accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Best hyperparameters:  {'C': 0.1, 'kernel': 'linear'}
# Best score:  0.8916666666666666
# Accuracy:  0.7096774193548387

# %%
y_pred_svc = cross_val_predict(estimator=svm, X=X_train, y=y_train, cv=5, method='predict', n_jobs=-1)
#y_pred_svc.round(2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeRegressor
DecisionTreeRegressorModel = DecisionTreeRegressor( max_depth=3,random_state=33)
DecisionTreeRegressorModel.fit(X_train, y_train)

#Calculating Details
print('DecisionTreeRegressor Train Score is : ' , DecisionTreeRegressorModel.score(X_train, y_train))
print('DecisionTreeRegressor Test Score is : ' , DecisionTreeRegressorModel.score(X_test, y_test))
print('----------------------------------------------------')
# Out:
# DecisionTreeRegressor Train Score is :  0.9997552438834794
# DecisionTreeRegressor Test Score is :  0.6134217293801285
# ----------------------------------------------------

# %%
y_pred_dec = DecisionTreeRegressorModel.predict(X_test)
print('Predicted Value for DecisionTreeRegressorModel is : ' , y_pred_dec[:10])
# Out:
# Predicted Value for DecisionTreeRegressorModel is :  [  5.35211268   5.35211268   5.35211268   5.35211268   5.35211268
#    5.35211268 300.         300.           5.35211268 300.        ]

# %%
from re import search
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
#from sklearn.datasets import load_boston
import numpy as np



# Define the parameter grid
param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 5, 10, 20]
}

# Create an instance of the decision tree regressor
tree = DecisionTreeRegressor(random_state=42)

# Create a GridSearchCV object
grid_search = GridSearchCV(tree, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the GridSearchCV object to the data
grid_search.fit(X_train, y_train)

# Print the best parameters and score
print("Best parameters: ", grid_search.best_params_)
print("Best score: ", np.sqrt(-grid_search.best_score_))
# Out:
# Best parameters:  {'max_depth': 6, 'min_samples_split': 2}
# Best score:  70.45536412036584

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=42)

xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

#display_scores(y_pred)
#compare_random(y_pred)
# Out:
# [13:10:41] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# score : 8.553728841027079
# Example of prediction
# Prediction : 4.972836494445801  True Value : 5.0

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor
sgd_reg = SGDRegressor(penalty='l2', alpha=0.00001, eta0=0.00001, shuffle=True, max_iter=10000)  ## with Regularization
sgd_reg.fit(X_train, y_train)
rmse_scores_sgd = cross_val_score(estimator=sgd_reg, X=X_train, y=y_train,
                               cv=5, scoring='neg_mean_squared_error', n_jobs=-1)  ## sklearn deals with error as negative
rmse_scores_sgd = -1 * rmse_scores_sgd   ## we want it positive
rmse_scores_sgd = np.sqrt(rmse_scores_sgd)
rmse_scores_sgd
# Out:
# array([3.44379239e+09, 1.09317363e+10, 2.36515263e+09, 6.78261306e+10,
#        3.07722414e+09])

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor, VotingRegressor
params_best_forest = {'n_estimators': np.arange(10, 200 , 2),
                      'max_depth': np.arange(10, 40),
                      'max_samples': [0.7, 0.8, 0.9, 1]}
forest_reg = RandomForestRegressor(n_estimators=150, max_depth=6, max_samples=0.8, random_state=42, n_jobs=-1)
forest_reg.fit(X_train, y_train)
## Intialize
search_random_forest = RandomizedSearchCV(estimator=forest_reg, param_distributions=params_best_forest,
                                          n_iter=20, scoring='neg_mean_squared_error',
                                          cv=5, verbose=6, random_state=422)
search_random_forest.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END max_depth=15, max_samples=1, n_estimators=140;, score=-146.875 total time=   0.3s
# [CV 2/5] END max_depth=15, max_samples=1, n_estimators=140;, score=-152.604 total time=   0.2s
# [CV 3/5] END max_depth=15, max_samples=1, n_estimators=140;, score=-155.166 total time=   0.3s
# [CV 4/5] END max_depth=15, max_samples=1, n_estimators=140;, score=-152.604 total time=   0.4s
# [CV 5/5] END max_depth=15, max_samples=1, n_estimators=140;, score=-154.124 total time=   0.4s
# [CV 1/5] END max_depth=17, max_samples=0.7, n_estimators=64;, score=-40.010 total time=   0.2s
# [CV 2/5] END max_depth=17, max_samples=0.7, n_estimators=64;, score=-20.695 total time=   0.2s
# [CV 3/5] END max_depth=17, max_samples=0.7, n_estimators=64;, score=-32.349 total time=   0.2s
# [CV 4/5] END max_depth=17, max_samples=0.7, n_estimators=64;, score=-25.438 total time=   0.2s
# ...

# %%
best_model = search_random_forest.best_estimator_
best_model
best_model = RandomForestRegressor(max_depth=14, max_samples=1, n_estimators=150, n_jobs=-1,
                      random_state=42)
best_model.fit(X_train , y_train)
# Out:
# RandomForestRegressor(max_depth=14, max_samples=1, n_estimators=150, n_jobs=-1,
#                       random_state=42)

# %%
best_model =RandomForestRegressor(max_depth=14, max_samples=1, n_estimators=150, n_jobs=-1,
                      random_state=42)
best_model.fit(X_train, y_train)
print('Random Forest Regressor Train Score is : ' , best_model.score(X_train, y_train))
print('Random Forest Regressor Test Score is : ' , best_model.score(X_test, y_test))
#print('Random Forest Regressor No. of features are : ' , best_model.n_features_)

y_pred = best_model.predict(X_test)
#print('Predicted Value for Random Forest Regressor is : ' , y_pred[:10])

#import joblib
#joblib.dump(best_model, 'model_randfor.pkl')
# Out:
# Random Forest Regressor Train Score is :  -0.04830135618758136
# Random Forest Regressor Test Score is :  -0.18509103519635772

# %%
#joblib.load('model_randfor.pkl')
# Out:
# RandomForestRegressor(max_depth=14, max_samples=1, n_estimators=150, n_jobs=-1,
#                       random_state=42)

# %%
y_pred_ron= cross_val_predict(estimator=best_model, X=X_train, y=y_train, cv=5, method='predict', n_jobs=-1)
#y_pred_ron.round(2)

# %%
import matplotlib.pyplot as plt

x_x = np.arange(0, 39)
plt.plot(x_x, y_train.values[1:40], 'r*-',  markersize=7, label='Ground Truth')  ## for train
plt.plot(x_x, y_pred_lin[1:40], 'ko--', markersize=7, label='DT')
plt.plot(x_x, y_pred_svc[1:40], 'bx-', markersize=7, label='SVM')
plt.title('Comparison between Models for 100 random points in Train Dataset', fontsize=14, color='k')
plt.xlabel('Points Number', fontsize=14, color='k')
plt.ylabel('Prediction (market value)', fontsize=14, color='k')
plt.legend()
plt.grid('on')
plt.show()

# %%
x_x = np.arange(0, 39)
plt.plot(x_x, y_train.values[1:40], 'r*-',  markersize=7, label='Ground Truth')  ## for train
plt.plot(x_x, y_pred_lin[1:40], 'ko--', markersize=7, label='DT')
plt.plot(x_x, y_pred_ron[1:40], 'bx-', markersize=7, label='RondomForest')
plt.title('Comparison between Models for 100 random points in Train Dataset', fontsize=14, color='k')
plt.xlabel('Points Number', fontsize=14, color='k')
plt.ylabel('Prediction (market value)', fontsize=14, color='k')
plt.legend()
plt.grid('on')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
import random
